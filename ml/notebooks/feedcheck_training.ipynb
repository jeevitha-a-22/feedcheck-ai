# %% [markdown]
# # FeedCheck AI - MobileNetV2 Silage Quality Training Notebook
# This notebook contains exploratory analysis, data augmentation, and transfer learning workflows.

# %%
# Setup environment and dependencies
import torch
from torchvision import models, transforms
print(f"PyTorch Version: {torch.__version__}")
